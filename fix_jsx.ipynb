# %% [markdown]
# # Fix JSX spacing issues in index.html
# This notebook detects and repairs malformed JSX tag spacing in the project `index.html`.

# %%
from pathlib import Path
import re
path = Path('c:/Users/catin/OneDrive/Documents/Godot/scouting/index.html')
text = path.read_text(encoding='utf-8')
print('Original length:', len(text))
print('Standalone less-than count:', text.count('<
'))
print('aria - label occurrences:', len(re.findall(r'aria*-*label', text)))
